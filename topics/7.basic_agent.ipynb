# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm=ChatOpenAI(model="gpt-4-0613", temperature=0.9)

# %%
from langchain.tools import tool
from langchain.agents import create_agent

# %%
@tool
def Add(a:int, b:int) -> int:
    """Add two numbers together.
    
    Args:
        a: First number to add.
        b: Second number to add.
    """
    
    return a + b

# %%
agent=create_agent(
    tools=[Add],
    model=llm,
    system_prompt="You are helpful math tutor add number using tools"
    
)

# %%
agent.invoke({"input": "Add 5 and 3 "})
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 72, 'total_tokens': 93, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-DEeGHABwutwattDfbBp1b9WpQzNjv', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019caa4d-74d4-76b3-9fcb-93defa8f9a93-0', tool_calls=[{'name': 'Add', 'args': {'a': 5, 'b': 7}, 'id': 'call_Q2DN8uugxDmvkVlKoBibXOeQ', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 72, 'output_tokens': 21, 'total_tokens': 93, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='12', name='Add', id='b3735279-e2c7-43b6-b5e7-0f75b2e47b69', tool_call_id='call_Q2DN8uugxDmvkVlKoBibXOeQ'),
#   AIMessage(content='The sum of 5 and 7 is 12.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 97, 'total_tokens': 110, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-DEeGJNnN425NjuyrrxgRYqYSf0n8f', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019caa4d-7b11-7a40-b316-715fea88e94e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 97, 'output_tokens': 13, 'total_tokens': 110, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
